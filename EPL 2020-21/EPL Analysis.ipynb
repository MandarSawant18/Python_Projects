# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
epl = pd.read_csv(r"C:\Users\smand\OneDrive\Desktop\DATA SCIENCE\Datasets\EPL_20_21.csv")

# %%
epl
# Out:
#                   Name              Club Nationality Position  Age  Matches  \
# 0          Mason Mount           Chelsea         ENG    MF,FW   21       36
# 1        Edouard Mendy           Chelsea         SEN       GK   28       31
# 2          Timo Werner           Chelsea         GER       FW   24       35
# 3         Ben Chilwell           Chelsea         ENG       DF   23       27
# 4          Reece James           Chelsea         ENG       DF   20       32
# ..                 ...               ...         ...      ...  ...      ...
# 527        Lys Mousset  Sheffield United         FRA    FW,MF   24       11
# 528     Jack O'Connell  Sheffield United         ENG       DF   26        2
# 529      Iliman Ndiaye  Sheffield United         FRA       MF   21        1
# 530  Antwoine Hackford  Sheffield United         ENG    DF,FW   16        1
# 531        Femi Seriki  Sheffield United         ENG       DF   17        1
#
# ...

# %%
epl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 532 entries, 0 to 531
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   532 non-null    object
#  1   Club                   532 non-null    object
#  2   Nationality            532 non-null    object
#  3   Position               532 non-null    object
#  4   Age                    532 non-null    int64
#  5   Matches                532 non-null    int64
#  6   Starts                 532 non-null    int64
#  7   Mins                   532 non-null    int64
#  8   Goals                  532 non-null    int64
#  9   Assists                532 non-null    int64
#  10  Passes_Attempted       532 non-null    int64
#  11  Perc_Passes_Completed  532 non-null    float64
#  12  Penalty_Goals          532 non-null    int64
#  13  Penalty_Attempted      532 non-null    int64
# ...

# %%
epl.describe().transpose()
# Out:
#                        count         mean          std   min     25%      50%  \
# Age                    532.0    25.500000     4.319404  16.0   22.00    26.00
# Matches                532.0    19.535714    11.840459   1.0    9.00    21.00
# Starts                 532.0    15.714286    11.921161   0.0    4.00    15.00
# Mins                   532.0  1411.443609  1043.171856   1.0  426.00  1345.00
# Goals                  532.0     1.853383     3.338009   0.0    0.00     1.00
# Assists                532.0     1.287594     2.095191   0.0    0.00     0.00
# Passes_Attempted       532.0   717.750000   631.372522   0.0  171.50   573.50
# Perc_Passes_Completed  532.0    77.823872    13.011631  -1.0   73.50    79.20
# Penalty_Goals          532.0     0.191729     0.850881   0.0    0.00     0.00
# Penalty_Attempted      532.0     0.234962     0.975818   0.0    0.00     0.00
# xG                     532.0     0.113289     0.148174   0.0    0.01     0.06
# ...

# %%
epl.isna().sum()
# Out:
# Name                     0
# Club                     0
# Nationality              0
# Position                 0
# Age                      0
# Matches                  0
# Starts                   0
# Mins                     0
# Goals                    0
# Assists                  0
# Passes_Attempted         0
# Perc_Passes_Completed    0
# Penalty_Goals            0
# Penalty_Attempted        0
# xG                       0
# xA                       0
# Yellow_Cards             0
# Red_Cards                0
# dtype: int64

# %%
epl['MinsPerGame'] = (epl['Mins']/epl['Matches']).astype(int)
epl['GoalsPerGame']= (epl['Goals']/epl['Matches']).astype(float)
epl
# Out:
#                   Name              Club Nationality Position  Age  Matches  \
# 0          Mason Mount           Chelsea         ENG    MF,FW   21       36
# 1        Edouard Mendy           Chelsea         SEN       GK   28       31
# 2          Timo Werner           Chelsea         GER       FW   24       35
# 3         Ben Chilwell           Chelsea         ENG       DF   23       27
# 4          Reece James           Chelsea         ENG       DF   20       32
# ..                 ...               ...         ...      ...  ...      ...
# 527        Lys Mousset  Sheffield United         FRA    FW,MF   24       11
# 528     Jack O'Connell  Sheffield United         ENG       DF   26        2
# 529      Iliman Ndiaye  Sheffield United         FRA       MF   21        1
# 530  Antwoine Hackford  Sheffield United         ENG    DF,FW   16        1
# 531        Femi Seriki  Sheffield United         ENG       DF   17        1
#
# ...

# %%
#Total Goals Scored in the league
total_goals = epl['Goals'].sum()
total_goals
# Out:
# 986

# %%
#Penalty Goals
total_pens = epl['Penalty_Goals'].sum()
total_pens
# Out:
# 102

# %%
#Penalties Attempted
total_pens_attempted = epl['Penalty_Attempted'].sum()
total_pens_attempted
# Out:
# 125

# %%
#Pie Chart to show pens scored vs missed
pens_not_scored = total_pens_attempted - total_pens
pens_not_scored
pie_data=[total_pens,pens_not_scored]
labels=['Penalties Scored', 'Penalties Missed']
colors=sns.color_palette('tab10')[2:4]

plt.figure(figsize=(12,5),dpi=90)
plt.pie(x=pie_data,labels=labels,colors= colors,startangle=60,labeldistance=1.1,autopct='%.0f%%')
plt.title("Penalties Converted VS Missed");

# %%
#Unique Positions
epl['Position'].unique()
# Out:
# array(['MF,FW', 'GK', 'FW', 'DF', 'MF', 'FW,MF', 'FW,DF', 'DF,MF',
#        'MF,DF', 'DF,FW'], dtype=object)

# %%
#Total FW players
epl[epl['Position']=='FW']
# Out:
#                    Name              Club Nationality Position  Age  Matches  \
# 2           Timo Werner           Chelsea         GER       FW   24       35
# 16        Tammy Abraham           Chelsea         ENG       FW   22       22
# 19       Olivier Giroud           Chelsea         FRA       FW   33       17
# 23   Ruben Loftus-Cheek           Chelsea         ENG       FW   24        1
# 30      Raheem Sterling   Manchester City         ENG       FW   25       31
# ..                  ...               ...         ...      ...  ...      ...
# 516        Oliver Burke  Sheffield United         SCO       FW   23       25
# 518     Oliver McBurnie  Sheffield United         SCO       FW   24       23
# 519      Rhian Brewster  Sheffield United         ENG       FW   20       27
# 523         Billy Sharp  Sheffield United         ENG       FW   34       16
# 526     Daniel Jebbison  Sheffield United         ENG       FW   17        4
#
# ...

# %%
#Total No of Nations
np.size(epl['Nationality'].unique())
# Out:
# 59

# %%
#Top 5 countries with most players
epl['Nationality'].value_counts()[0:10]
# Out:
# ENG    192
# FRA     31
# BRA     27
# ESP     26
# POR     21
# IRL     21
# SCO     20
# NED     16
# WAL     12
# BEL     11
# Name: Nationality, dtype: int64

# %%
nations = epl.groupby('Nationality').size().sort_values(ascending=False)
top_ten_countries = nations.head(10)

fig = top_ten_countries.plot(kind='bar',figsize=(12,6),color =sns.color_palette('tab10'))
for p in fig.patches:
       fig.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+p.get_width()/2, p.get_height()+0.9),xytext=(0,4),ha ='center', va='center', textcoords='offset points')
plt.ylabel('Count of Players')
plt.title('Top 10 Countries with Max Players')
# Out:
# Text(0.5, 1.0, 'Top 10 Countries with Max Players')

# %%
#Clubs with Most Players
most_players_clubwise = epl['Club'].value_counts().nlargest(5)
fig = most_players_clubwise.plot(kind='bar',figsize=(12,6),color=sns.color_palette('Set2'))
for p in fig.patches:
       fig.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+p.get_width()/2, p.get_height()+0.2),xytext=(0,4),ha ='center', va='center', textcoords='offset points')
plt.ylabel('Count of Players')
plt.title('Top 5 Clubs with Max Players')
plt.xticks(rotation=50,fontsize=12);

# %%
#Clubs with Least Players
least_players_clubwise = epl['Club'].value_counts().nsmallest(5)
fig = least_players_clubwise.plot(kind='bar',figsize=(12,6),color=sns.color_palette('Set2'))
for p in fig.patches:
       fig.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+p.get_width()/2, p.get_height()+0.2),xytext=(0,4),ha ='center', va='center', textcoords='offset points')
plt.ylabel('Count of Players')
plt.title('Top 5 Clubs with Least Players')
plt.xticks(rotation=50,fontsize=12);

# %%
#Age wise Player Distribution

Under20 = epl[epl['Age']<=20]
Between20_25 =epl[(epl['Age']>20) & (epl['Age']<=25)]
Between25_30 =epl[(epl['Age']>25) & (epl['Age']<=30)]
Above30 = epl[epl['Age']>30]

# %%
plt.figure(figsize=(5,5),dpi=100)
pie_data2 = np.array([Under20['Name'].count(),Between20_25['Name'].count(),Between25_30['Name'].count(),Above30['Name'].count()])
labels2 = ['20 or below','21-25','26-30','Above 30']
colors = ['#56a0d3', '#d4af37', '#006b3c', '#7c0a02']
plt.pie(x=pie_data2,labels=labels2,startangle=90,shadow= True,autopct='%.0f%%',colors = colors,radius=0.8)
plt.title("Age Wise Distribution of Players in EPL", fontsize=8);

# %%
#Total Under 20 Players in Each Club
players_under_20 = epl[epl['Age']<20]
plt.figure(figsize=(10,4),dpi=100)
fig = players_under_20['Club'].value_counts().plot(kind='bar',color = sns.color_palette('tab10'))
plt.title('Clubwise U-20 Player Count', fontsize=12)
plt.xlabel('Teams')
plt.ylabel('No of Players')
plt.xticks(rotation =90)
for p in fig.patches:
       fig.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+p.get_width()/2, p.get_height()),xytext=(0,4),ha ='center', va='center', textcoords='offset points')

# %%
#Under 20 players at Man Utd
players_under_20[players_under_20['Club']=='Manchester United']
# Out:
#                    Name               Club Nationality Position  Age  Matches  \
# 61      Mason Greenwood  Manchester United         ENG       FW   18       31
# 72     Brandon Williams  Manchester United         ENG       DF   19        4
# 73          Amad Diallo  Manchester United         CIV       FW   18        3
# 74       Anthony Elanga  Manchester United         SWE       FW   18        2
# 76      Shola Shoretire  Manchester United         ENG       FW   16        2
# 78      Hannibal Mejbri  Manchester United         FRA       MF   17        1
# 79  William Thomas Fish  Manchester United         ENG       DF   17        1
#
#     Starts  Mins  Goals  Assists  Passes_Attempted  Perc_Passes_Completed  \
# 61      21  1822      7        2               732                   83.1
# 72       2   188      0        0               140                   85.7
# 73       2   166      0        1                64                   84.4
# ...

# %%
#Average Age of Players in Each Club
plt.figure(figsize=(12,5),dpi=120)
plt.xticks(rotation=90)
sns.boxplot(data=epl, x='Club', y = 'Age')
plt.xlabel("Clubs");

# %%
num_players = epl.groupby('Club').size()
(epl.groupby('Club').sum()['Age']/num_players).sort_values(ascending = False)
# Out:
# Club
# Crystal Palace             28.333333
# West Ham United            27.500000
# Burnley                    27.040000
# West Bromwich Albion       26.766667
# Newcastle United           26.074074
# Manchester City            25.708333
# Tottenham Hotspur          25.625000
# Leicester City             25.592593
# Chelsea                    25.592593
# Liverpool FC               25.571429
# Everton                    25.413793
# Leeds United               25.347826
# Fulham                     25.035714
# Arsenal                    24.965517
# Sheffield United           24.814815
# Brighton                   24.555556
# Wolverhampton Wanderers    24.444444
# Aston Villa                24.291667
# Southampton                24.137931
# Manchester United          23.862069
# dtype: float64

# %%
#Total Assists From Each Club
plt.figure(figsize=(15,7),dpi=120)
fig = epl.groupby('Club').sum()['Assists'].sort_values(ascending=True).plot(kind='bar', color= sns.color_palette('tab10'))
plt.ylabel("Assists", fontsize=12)
plt.xlabel("Clubs", fontsize=12)
plt.title("Clubwise Assists", fontsize = 15)
for p in fig.patches:
       fig.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+p.get_width()/2, p.get_height()+0.2),xytext=(0,4),ha ='center', va='center', textcoords='offset points')

# %%
#Top 10 Assists
epl[['Name', 'Club', 'Assists', 'Matches']].nlargest(n=10, columns = 'Assists')
# Out:
#                      Name               Club  Assists  Matches
# 162            Harry Kane  Tottenham Hotspur       14       35
# 34        Kevin De Bruyne    Manchester City       12       25
# 51        Bruno Fernandes  Manchester United       12       37
# 161         Son Heung-min  Tottenham Hotspur       10       37
# 273         Jack Grealish        Aston Villa       10       26
# 54        Marcus Rashford  Manchester United        9       37
# 110           Jamie Vardy     Leicester City        9       34
# 220  Raphael Dias Belloli       Leeds United        9       30
# 2             Timo Werner            Chelsea        8       35
# 136       Aaron Cresswell    West Ham United        8       36

# %%
#Total Goals by Each Club
plt.figure(figsize=(15,7), dpi=120)
fig = epl.groupby('Club').sum()['Goals'].sort_values(ascending = False).plot(kind= 'bar', color = sns.color_palette('tab10'))
plt.ylabel("Goals", fontsize=12)
plt.xlabel("Clubs", fontsize=12)
plt.title("Clubwise Goals", fontsize = 15)
for p in fig.patches:
       fig.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+p.get_width()/2, p.get_height()+0.2),xytext=(0,4),ha ='center', va='center', textcoords='offset points')

# %%
#Most Goals
epl[['Name', 'Club', 'Goals', 'Matches']].nlargest(n=10, columns = 'Goals')
# Out:
#                       Name               Club  Goals  Matches
# 162             Harry Kane  Tottenham Hotspur     23       35
# 81           Mohamed Salah       Liverpool FC     22       37
# 51         Bruno Fernandes  Manchester United     18       37
# 161          Son Heung-min  Tottenham Hotspur     17       37
# 214        Patrick Bamford       Leeds United     17       38
# 237  Dominic Calvert-Lewin            Everton     16       33
# 110            Jamie Vardy     Leicester City     15       34
# 267          Ollie Watkins        Aston Villa     14       37
# 33          İlkay Gündoğan    Manchester City     13       28
# 191    Alexandre Lacazette            Arsenal     13       31

# %%
#Goals with and without assists
total_assists = epl['Assists'].sum()
goals_without_assists = total_goals-total_assists

plt.figure(figsize=(10,4),dpi=100)
plt.title('Distribution of Goals')
pie_data3 = [total_assists, goals_without_assists]
labels3 = ['Goals with Assists', 'Goals without Assists']
plt.pie(x=pie_data3, labels = labels3, startangle =90, autopct='%.0f%%');

# %%
#Top 10 players with most yellow cards
epl[['Name','Club','Yellow_Cards']].nlargest(n=10, columns = 'Yellow_Cards' )
# Out:
#                 Name                  Club  Yellow_Cards
# 266      John McGinn           Aston Villa            12
# 53     Harry Maguire     Manchester United            11
# 480  Conor Gallagher  West Bromwich Albion            11
# 218  Kalvin Phillips          Leeds United            10
# 270     Douglas Luiz           Aston Villa            10
# 159  Pierre Højbjerg     Tottenham Hotspur             9
# 242    Mason Holgate               Everton             9
# 55         Luke Shaw     Manchester United             8
# 189  Héctor Bellerín               Arsenal             8
# 272       Matty Cash           Aston Villa             8
